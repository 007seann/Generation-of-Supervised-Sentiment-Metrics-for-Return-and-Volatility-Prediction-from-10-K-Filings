# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the data starting from the correct line that contains the header
file_path = "/Users/apple/PROJECT/Hons-project/graph/MacroTrends_Data_Download_AAPL.csv"
data = pd.read_csv(file_path, skiprows=14)
start_date = '2006-01-01'
end_date = '2023-12-31'

# %%
data = data[(data['date'] >= start_date) & (data['date'] <= end_date)]

# %%
plt.figure(figsize=(14, 7))
plt.plot(data['date'], data['close'], label='Closing Price')
plt.title('AAPL Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Load the data starting from the correct line that contains the header
file_path = "/Users/apple/PROJECT/Hons-project/graph/MacroTrends_Data_Download_AAPL.csv"
data = pd.read_csv(file_path, skiprows=14)

# Convert the 'date' column to datetime format for proper plotting
# Define the start and end dates for the slice
start_date = '2006-01-01'
end_date = '2023-12-31'

# Convert the start and end dates to datetime
# start_date = pd.to_datetime(start_date)
# end_date = pd.to_datetime(end_date)

# Slice the dataframe to include only the specified date range
sliced_data = data[(data['date'] >= start_date) & (data['date'] <= end_date)]

# Plotting the closing price over time

plt.figure(figsize=(14, 7))
plt.plot(data['date'], data['close'], label='Closing Price')
plt.title('AAPL Stock Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 27
#      25 plt.legend()
#      26 plt.grid(True)
# ---> 27 plt.xticks(rotation=45)
#      28 plt.tight_layout()
#      29 plt.show()
#
# File ~/miniconda3/envs/hons-project/lib/python3.8/site-packages/matplotlib/pyplot.py:1889, in xticks(ticks, labels, minor, **kwargs)
#    1886     locs = ax.set_xticks(ticks, minor=minor)
#    1888 if labels is None:
# -> 1889     labels = ax.get_xticklabels(minor=minor)
#    1890     for l in labels:
#    1891         l._internal_update(kwargs)
#
# File ~/miniconda3/envs/hons-project/lib/python3.8/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# ...

# %%
data['date']
# Out:
# 0        1980-12-12
# 1        1980-12-15
# 2        1980-12-16
# 3        1980-12-17
# 4        1980-12-18
#             ...
# 10879    2024-02-09
# 10880    2024-02-12
# 10881    2024-02-13
# 10882    2024-02-14
# 10883    2024-02-15
# Name: date, Length: 10884, dtype: object
