# %%
import requests
import os
import pandas as pd
import json
from tqdm import tqdm

# %%
ids_path = '/Users/apple/PROJECT/analaysis_reports/test'
jsons = os.listdir(ids_path)

for json_file in jsons:
    file_path = os.path.join(ids_path, json_file)
    with open(file_path, 'r') as f:
        data = json.load(f)
        data = data['data']
        print(len(data))
        ids = data[0]['id']
        print(data)
        print(ids)
# Out:
# 40
# ...

# %%
print(data[0]['id'])
# Out:
# 4659770
