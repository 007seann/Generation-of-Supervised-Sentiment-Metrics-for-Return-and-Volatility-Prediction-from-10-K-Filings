# %% [markdown]
# ## This code illustrates how to get S&P500 index constituents and their identifiers from CRSP and Compustat
# - Researchers used to be able to extract index membership information from Compustat's "comp.idxcst_his" data. Now that S&P pulled this piece of data off from WRDS platform, we have to turn to CRSP to get S&P500 Index membership data.
# - Unfortunately, there is no easy way to uncover constituents info for the other indices covered by "comp.idxcst_his".

# %%
# !brew install postgresql
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 5 taps (heroku/brew, shivammathur/php, coursier/formulas, homebrew/core and homebrew/cask).
# ==> New Formulae
# action-docs                langgraph-cli              sf
# ansible-builder            lbfgspp                    sleek
# boring                     libmsquic                  surfer
# carapace                   libspelling@0.2            termscp
# clickhouse-sql-parser      localai                    tex-fmt
# decasify                   markdown-oxide             toml2json
# dipc                       minijinja-cli              vipsdisp
# distill-cli                node@22                    wasi-libc
# fcft                       pytest                     wasi-runtimes
# foot                       python-freethreading       wasm-component-ld
# hawkeye                    recc                       zizmor
# icu4c@74                   rip2                       zsh-system-clipboard
# icu4c@76                   rust-script
# kubetail                   sequoia-sq
# ==> New Casks
# acronis-true-image-cleanup-tool          font-zpix
# adlock                                   github-copilot-for-xcode
# backyard-ai                              huggingchat
# bentobox                                 huly
# claude                                   hyperconnect
# cocoapacketanalyzer                      jet-pilot
# default-handler                          langgraph-studio
# displaybuddy                             legcord
# dockside                                 lets
# follow                                   magicquit
# follow@alpha                             mailbird
# follow@nightly                           mailsteward
# font-doto                                morisawa-desktop-manager
# font-eldur                               singlebox
# font-faculty-glyphic                     sketchup
# font-greybeard                           unraid-usb-creator-next
# font-host-grotesk                        viz
# font-mynaui-icons                        webkinz
# font-recursive-desktop                   yellowdot
# ==> Deleted Installed Formulae
# icu4c ✘
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
#
# You have 28 outdated formulae installed.
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
#
# Warning: Formula postgresql was renamed to postgresql@14.
# ==> Downloading https://ghcr.io/v2/homebrew/core/postgresql/14/manifests/14.13_3
# ######################################################################### 100.0%
# ==> Fetching dependencies for postgresql@14: icu4c@76 and openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/76/manifests/76.1_1
# ######################################################################### 100.0%
# ==> Fetching icu4c@76
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/76/blobs/sha256:f7e042054
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.4.0
# ######################################################################### 100.0%
# ==> Fetching openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/blobs/sha256:28e2abc9
# ######################################################################### 100.0%
# ==> Fetching postgresql@14
# ==> Downloading https://ghcr.io/v2/homebrew/core/postgresql/14/blobs/sha256:bc88
# ######################################################################### 100.0%
# ==> Installing dependencies for postgresql@14: icu4c@76 and openssl@3
# ==> Installing postgresql@14 dependency: icu4c@76
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/76/manifests/76.1_1
# Already downloaded: /Users/apple/Library/Caches/Homebrew/downloads/c105f8980d3a6b0ff0253b47492e886520580406ee75fa52509cf5b251b4d633--icu4c@76-76.1_1.bottle_manifest.json
# ==> Pouring icu4c@76--76.1_1.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/icu4c@76/76.1_1: 277 files, 79.9MB
# ==> Installing postgresql@14 dependency: openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.4.0
# Already downloaded: /Users/apple/Library/Caches/Homebrew/downloads/a8a169d38329b14f967d497d0ea77eee6dc5444175093fc7b26026b357e81736--openssl@3-3.4.0.bottle_manifest.json
# ==> Pouring openssl@3--3.4.0.sonoma.bottle.tar.gz
# 🍺  /usr/local/Cellar/openssl@3/3.4.0: 7,236 files, 33.8MB
# ==> Installing postgresql@14
# ==> Pouring postgresql@14--14.13_3.sonoma.bottle.tar.gz
# ==> /usr/local/Cellar/postgresql@14/14.13_3/bin/initdb --locale=C -E UTF-8 /usr/
# ==> Caveats
# This formula has created a default database cluster with:
#   initdb --locale=C -E UTF-8 /usr/local/var/postgresql@14
#
# To start postgresql@14 now and restart at login:
#   brew services start postgresql@14
# Or, if you don't want/need a background service you can just run:
#   /usr/local/opt/postgresql@14/bin/postgres -D /usr/local/var/postgresql@14
# ==> Summary
# 🍺  /usr/local/Cellar/postgresql@14/14.13_3: 3,323 files, 41.9MB
# ==> Running `brew cleanup postgresql@14`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /Users/apple/Library/Caches/Homebrew/bison--3.8.2... (1MB)
# Removing: /Users/apple/Library/Caches/Homebrew/cairo--1.18.2... (779.7KB)
# Removing: /Users/apple/Library/Caches/Homebrew/capstone--5.0.3... (3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/cmake--3.30.5... (17.7MB)
# Removing: /Users/apple/Library/Caches/Homebrew/coursier--2.1.14.gz... (19.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/coursier--jar-launcher--2.1.14... (159KB)
# Removing: /Users/apple/Library/Caches/Homebrew/curl--8.10.1... (1.4MB)
# Removing: /Users/apple/Library/Caches/Homebrew/dtc--1.7.1... (138.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/freetype--2.13.3... (969.1KB)
# Removing: /Users/apple/Library/Caches/Homebrew/fzf--0.55.0... (1.7MB)
# Removing: /Users/apple/Library/Caches/Homebrew/gcc--14.2.0... (158.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/gdbm--1.24... (275.8KB)
# Removing: /Users/apple/Library/Caches/Homebrew/gettext_bottle_manifest--0.22.5... (11.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/gettext--0.22.5... (10.2MB)
# Removing: /Users/apple/Library/Caches/Homebrew/giflib--5.2.2... (151.9KB)
# Removing: /Users/apple/Library/Caches/Homebrew/glib--2.82.1.tar.xz... (5.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/gnutls--3.8.4... (3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/graphviz--12.1.2... (3.0MB)
# Removing: /Users/apple/Library/Caches/Homebrew/harfbuzz--10.0.1_1... (2.6MB)
# Removing: /Users/apple/Library/Caches/Homebrew/heroku--9.3.0.tar.xz... (49.6MB)
# Removing: /Users/apple/Library/Caches/Homebrew/icu4c@75--75.1... (28.9MB)
# Removing: /usr/local/Cellar/icu4c/74.2... (271 files, 77.4MB)
# Removing: /Users/apple/Library/Caches/Homebrew/libnghttp2--1.63.0... (221.8KB)
# Removing: /Users/apple/Library/Caches/Homebrew/libpq--17.0_1... (7.1MB)
# Removing: /Users/apple/Library/Caches/Homebrew/libslirp--4.8.0... (139.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/libssh--0.11.1... (502.2KB)
# Removing: /Users/apple/Library/Caches/Homebrew/libtool--2.5.3... (1MB)
# Removing: /Users/apple/Library/Caches/Homebrew/libunistring--1.2... (1.6MB)
# Removing: /Users/apple/Library/Caches/Homebrew/libusb--1.0.27... (174.4KB)
# Removing: /Users/apple/Library/Caches/Homebrew/libx11--1.8.10... (2.2MB)
# Removing: /Users/apple/Library/Caches/Homebrew/libxcb--1.17.0... (947.9KB)
# Removing: /Users/apple/Library/Caches/Homebrew/libxdmcp--1.1.5... (35.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/libxext--1.3.6... (106.4KB)
# Removing: /Users/apple/Library/Caches/Homebrew/lima--0.23.2... (58.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/lz4--1.10.0... (301.3KB)
# Removing: /Users/apple/Library/Caches/Homebrew/meson--1.5.2... (818.2KB)
# Removing: /Users/apple/Library/Caches/Homebrew/mpdecimal--4.0.0... (184.1KB)
# Removing: /Users/apple/Library/Caches/Homebrew/nasm--2.16.03... (502.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/ncurses--6.5... (2.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/nettle--3.10... (1011KB)
# Removing: /Users/apple/Library/Caches/Homebrew/ninja--1.12.1... (161.8KB)
# Removing: /Users/apple/Library/Caches/Homebrew/openjdk--23.tar.gz... (111.2MB)
# Removing: /Users/apple/Library/Caches/Homebrew/openjdk@11--11.0.24... (181.2MB)
# Removing: /Users/apple/Library/Caches/Homebrew/openssl@1.1--1.1.1w... (5.2MB)
# Removing: /usr/local/Cellar/openssl@3/3.3.2... (6,984 files, 33MB)
# Removing: /Users/apple/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.3.2... (13KB)
# Removing: /Users/apple/Library/Caches/Homebrew/openssl@3--3.3.2... (8.8MB)
# Removing: /Users/apple/Library/Caches/Homebrew/p11-kit--0.25.5... (927.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/pcre2--10.44... (2.1MB)
# Removing: /Users/apple/Library/Caches/Homebrew/php@7.4--7.4.33_6... (18.1MB)
# Removing: /Users/apple/Library/Caches/Homebrew/pyenv--2.4.14... (789.5KB)
# Removing: /Users/apple/Library/Caches/Homebrew/python-packaging--24.1... (100.9KB)
# Removing: /Users/apple/Library/Caches/Homebrew/python-setuptools--75.1.0_1... (2MB)
# Removing: /Users/apple/Library/Caches/Homebrew/qemu--9.1.0... (107.2MB)
# Removing: /Users/apple/Library/Caches/Homebrew/readline--8.2.13... (550.2KB)
# Removing: /Users/apple/Library/Caches/Homebrew/sbt--1.10.2... (3.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/snappy--1.2.1... (49.0KB)
# Removing: /Users/apple/Library/Caches/Homebrew/sqlite--3.46.1... (2.3MB)
# Removing: /Users/apple/Library/Caches/Homebrew/unbound--1.21.1... (2.9MB)
# Removing: /Users/apple/Library/Caches/Homebrew/wget--1.24.5... (1.5MB)
# Removing: /Users/apple/Library/Caches/Homebrew/xorgproto--2024.1... (699.7KB)
# Removing: /Users/apple/Library/Caches/Homebrew/xz--5.6.3... (565.8KB)
# Removing: /Users/apple/Library/Caches/Homebrew/zstd--1.5.6... (991.2KB)
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
# Removing: /Users/apple/Library/Caches/Homebrew/icu4c--74.2... (28.7MB)
# Removing: /Users/apple/Library/Caches/Homebrew/icu4c_bottle_manifest--74.2... (9.8KB)
# Removing: /Users/apple/Library/Caches/Homebrew/java_cache... (49 files, 39MB)
# Error: Unexpected method 'appcast' called on Cask adoptopenjdk8.
# Follow the instructions here:
#   https://github.com/Homebrew/homebrew-cask#reporting-bugs
# Removing: /Users/apple/Library/Caches/Homebrew/api-source/Homebrew/homebrew-core/e9baecfdd4218a6482507ee2f519fbb8014ca3b6/Formula/gobject-introspection.rb... (4.2KB)
# Removing: /Users/apple/Library/Caches/Homebrew/api-source/Homebrew/homebrew-core/e9baecfdd4218a6482507ee2f519fbb8014ca3b6/Formula/harfbuzz.rb... (2.3KB)
# Removing: /Users/apple/Library/Caches/Homebrew/api-source/Homebrew/homebrew-core/e9baecfdd4218a6482507ee2f519fbb8014ca3b6/Formula/libtiff.rb... (2KB)
# Removing: /Users/apple/Library/Caches/Homebrew/api-source/Homebrew/homebrew-core/e9baecfdd4218a6482507ee2f519fbb8014ca3b6/Formula/openjdk.rb... (6.5KB)
# Removing: /Users/apple/Library/Logs/Homebrew/libtiff... (6 files, 581.1KB)
# Removing: /Users/apple/Library/Logs/Homebrew/libpng... (8 files, 182.0KB)
# Removing: /Users/apple/Library/Logs/Homebrew/harfbuzz... (7 files, 696.6KB)
# Removing: /Users/apple/Library/Logs/Homebrew/python@3.12... (2 files, 2KB)
# Removing: /Users/apple/Library/Logs/Homebrew/glib... (18 files, 8.1MB)
# Removing: /Users/apple/Library/Logs/Homebrew/gobject-introspection... (13 files, 1.5MB)
# Removing: /Users/apple/Library/Logs/Homebrew/openjdk... (6 files, 15.2MB)
# Removing: /Users/apple/Library/Logs/Homebrew/openssl@3... (64B)
# Removing: /Users/apple/Library/Logs/Homebrew/ca-certificates... (64B)
# Removing: /Users/apple/Library/Logs/Homebrew/openssl@1.1... (64B)
# Removing: /Users/apple/Library/Logs/Homebrew/unbound... (64B)
# Removing: /Users/apple/Library/Logs/Homebrew/python@3.7... (64B)
# Removing: /Users/apple/Library/Logs/Homebrew/jpeg-turbo... (11 files, 1.3MB)
# Removing: /Users/apple/Library/Logs/Homebrew/gnutls... (64B)
# Pruned 2 symbolic links and 6 directories from /usr/local
# ==> Caveats
# ==> postgresql@14
# This formula has created a default database cluster with:
#   initdb --locale=C -E UTF-8 /usr/local/var/postgresql@14
#
# To start postgresql@14 now and restart at login:
#   brew services start postgresql@14
# Or, if you don't want/need a background service you can just run:
#   /usr/local/opt/postgresql@14/bin/postgres -D /usr/local/var/postgresql@14

# %%
# !pip install wrds
# Out:
# Collecting wrds
#   Using cached wrds-3.2.0-py3-none-any.whl.metadata (5.8 kB)
# INFO: pip is looking at multiple versions of wrds to determine which version is compatible with other requirements. This could take a while.
#   Using cached wrds-3.1.6-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from wrds) (1.24.4)
# Requirement already satisfied: pandas in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from wrds) (2.0.3)
# Collecting psycopg2-binary (from wrds)
#   Using cached psycopg2-binary-2.9.10.tar.gz (385 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from wrds) (1.10.1)
# Requirement already satisfied: sqlalchemy<2 in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from wrds) (1.4.48)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from pandas->wrds) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from pandas->wrds) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/apple/miniconda3/envs/hons-project/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->wrds) (1.16.0)
# Downloading wrds-3.1.6-py3-none-any.whl (12 kB)
# Building wheels for collected packages: psycopg2-binary
#   Building wheel for psycopg2-binary (setup.py) ... done
#   Created wheel for psycopg2-binary: filename=psycopg2_binary-2.9.10-cp38-cp38-macosx_10_9_x86_64.whl size=143865 sha256=9efef57799e02bd074f983f118125a3efc648205c7c64f6b13076794bd9b0310
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/df/fb/7d/c43b1faf8e1ae26e14d1e183eca11ef5560125067a34948080
# Successfully built psycopg2-binary
# Installing collected packages: psycopg2-binary, wrds
# Successfully installed psycopg2-binary-2.9.10 wrds-3.1.6
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
##########################################
# S&P 500 Index Constituents             #
# Qingyi (Freda) Song Drechsler          #
# Date: October 2020                     #
##########################################

import pandas as pd
import wrds

# %% [markdown]
# ### Step 1: Connect to WRDS

# %%
###################
# Connect to WRDS #
###################
conn=wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %% [markdown]
# ### Step 2: Get SP500 Index Membership from CRSP
# - I opt for the monthly frequency of the data, but one can choose to work with crsp.dsp500list if more precise date range is needed.

# %%
sp500 = conn.raw_sql("""
                        select a.*, b.date, b.ret
                        from crsp.msp500list as a,
                        crsp.msf as b
                        where a.permno=b.permno
                        and b.date >= a.start and b.date<= a.ending
                        and b.date>='01/01/2000'
                        order by date;
                        """, date_cols=['start', 'ending', 'date'])

# %%
sp500.head()
# Out:
#    permno      start     ending       date       ret
# 0   77178 1999-07-22 2023-12-29 2000-01-31 -0.278921
# 1   48485 1976-07-01 2006-03-31 2000-01-31 -0.139194
# 2   19502 1979-10-11 2023-12-29 2000-01-31 -0.044872
# 3   28847 1986-12-18 2002-05-14 2000-01-31 -0.311891
# 4   56573 1986-02-13 2023-12-29 2000-01-31 -0.134135

# %% [markdown]
# ### Step 3: Add Other Company Identifiers from CRSP.MSENAMES
# - You don't need this step if only PERMNO is required
# - This step aims to add TICKER, SHRCD, EXCHCD and etc.

# %%
# Add Other Descriptive Variables

mse = conn.raw_sql("""
                        select comnam, ncusip, namedt, nameendt, 
                        permno, shrcd, exchcd, hsiccd, ticker
                        from crsp.msenames
                        """, date_cols=['namedt', 'nameendt'])

# if nameendt is missing then set to today date
mse['nameendt']=mse['nameendt'].fillna(pd.to_datetime('today'))

# %%
mse.sample(5)
# Out:
#                                comnam    ncusip     namedt   nameendt  permno  \
# 39745               PRESTON MINES LTD      None 1962-07-02 1968-01-01   35588
# 78642        LAFAYETTE INDUSTRIES INC  50637710 1995-07-13 1996-05-08   80938
# 72228  SAPIENS INTERNATIONAL CORP N V  N7716A10 1992-05-29 1995-07-19   78759
# 93645           INTERSTATE HOTEL CORP  46088R10 1999-06-18 2002-07-31   86973
# 64298         FUTURE GERMANY FUND INC  36090510 1990-02-28 1995-06-29   76083
#
#        shrcd  exchcd  hsiccd ticker
# 39745     10       2    1081    PRS
# 78642     11       3    2542   LAFI
# 72228     12       3    7372  SPNSF
# 93645     11       3    7010   IHCO
# 64298     14       1    6722    FGF

# %%
# Merge with SP500 data
sp500_full = pd.merge(sp500, mse, how = 'left', on = 'permno')

# Impose the date range restrictions
sp500_full = sp500_full.loc[(sp500_full.date>=sp500_full.namedt) \
                            & (sp500_full.date<=sp500_full.nameendt)]
sp500_full.sample(5)
# Out:
#          permno      start     ending       date       ret            comnam  \
# 108839    41080 1965-01-07 2023-12-29 2002-05-31 -0.127850       CUMMINS INC
# 922870    60599 1999-03-25 2023-03-17 2020-04-30  0.122622   CENTURYLINK INC
# 1028182   89269 2016-03-30 2023-12-29 2022-10-31  0.094075  CENTENE CORP DEL
# 6894      64995 1994-03-02 2023-12-29 2000-02-29 -0.180119       KEYCORP NEW
# 1009078   76095 2016-03-30 2023-12-29 2022-04-29 -0.062874       HOLOGIC INC
#
#            ncusip     namedt   nameendt  shrcd  exchcd  hsiccd ticker
# 108839   23102110 2002-01-02 2003-12-09     11       1    3519    CUM
# 922870   15670010 2014-02-13 2020-09-17     11       1    4812    CTL
# 1028182  15135B10 2014-01-29 2023-12-29     11       1    6324    CNC
# 6894     49326710 1994-03-02 2002-01-01     11       1    6021    KEY
# 1009078  43644010 2018-01-29 2023-12-29     11       3    3844   HOLX

# %% [markdown]
# ### Step 4: Add Compustat Identifiers
# - Link with Compustat's GVKEY and IID if need to work with fundamental data
# - Linkage is done through crsp.ccmxpf_linktable

# %%
# Linking with Compustat through CCM

ccm=conn.raw_sql("""
                  select gvkey, liid as iid, lpermno as permno, linktype, linkprim, 
                  linkdt, linkenddt
                  from crsp.ccmxpf_linktable
                  where substr(linktype,1,1)='L'
                  and (linkprim ='C' or linkprim='P')
                  """, date_cols=['linkdt', 'linkenddt'])

# if linkenddt is missing then set to today date
ccm['linkenddt']=ccm['linkenddt'].fillna(pd.to_datetime('today'))

# %%
# Merge the CCM data with S&P500 data
# First just link by matching PERMNO
sp500ccm = pd.merge(sp500_full, ccm, how='left', on=['permno'])

# Then set link date bounds
sp500ccm = sp500ccm.loc[(sp500ccm['date']>=sp500ccm['linkdt'])\
                        &(sp500ccm['date']<=sp500ccm['linkenddt'])]
sp500ccm.sample(5)
# Out:
#          permno      start     ending       date       ret  \
# 42113   48274.0 1989-08-03 2011-12-12 2005-05-31  0.068434
# 21022   27887.0 1972-09-14 2019-12-31 2002-08-30 -0.090704
# 81974   90829.0 2008-08-27 2019-12-31 2010-08-31  0.140535
# 39158   13856.0 1957-03-01 2019-12-31 2004-12-31  0.050491
# 137326  71175.0 1994-03-11 2019-12-31 2018-02-28 -0.041925
#
#                              comnam    ncusip     namedt   nameendt  shrcd  \
# 42113                     NICOR INC  65408610 2004-06-10 2011-12-09   11.0
# 21022      BAXTER INTERNATIONAL INC  07181310 2002-02-01 2004-02-16   11.0
# 81974   C F INDUSTRIES HOLDINGS INC  12526910 2005-08-11 2019-12-31   11.0
# 39158                   PEPSICO INC  71344810 2004-06-10 2017-12-19   11.0
# 137326                   UNUM GROUP  91529Y10 2007-03-02 2019-09-11   11.0
#
#         exchcd  hsiccd ticker   gvkey iid linktype linkprim     linkdt  \
# 42113      1.0  4924.0    GAS  007904  01       LC        P 1969-05-02
# 21022      1.0  3841.0    BAX  002086  01       LC        P 1962-01-31
# 81974      1.0  2873.0     CF  163946  01       LC        P 2005-08-11
# 39158      1.0  2086.0    PEP  008479  01       LC        P 1962-01-31
# 137326     1.0  6321.0    UNM  012726  01       LU        P 1986-12-31
#
#                         linkenddt
# 42113  2011-12-30 00:00:00.000000
# 21022  2020-10-21 14:26:10.563769
# 81974  2020-10-21 14:26:10.563769
# 39158  2020-10-21 14:26:10.563769
# 137326 2020-10-21 14:26:10.563769

# %%
# Rearrange columns for final output

sp500ccm = sp500ccm.drop(columns=['namedt', 'nameendt', \
                                  'linktype', 'linkprim', 'linkdt', 'linkenddt'])
sp500ccm = sp500ccm[['date', 'permno', 'comnam', 'ncusip', 'shrcd', 'exchcd', 'hsiccd', 'ticker', \
                     'gvkey', 'iid', 'start', 'ending', 'ret']]
sp500ccm.sample(5)
# Out:
#              date   permno                         comnam    ncusip  shrcd  \
# 49267  2006-04-28  86102.0     FEDERATED INVESTORS INC PA  31421110   11.0
# 120416 2015-11-30  81910.0                    INVESCO LTD  G491BT10   12.0
# 112968 2014-11-28  78975.0                     INTUIT INC  46120210   11.0
# 19214  2002-05-31  64186.0                 C I G N A CORP  12550910   11.0
# 134250 2017-09-29  15707.0  HEWLETT PACKARD ENTERPRISE CO  42824C10   11.0
#
#         exchcd  hsiccd ticker   gvkey iid      start     ending       ret
# 49267      1.0  6282.0    FII  066731  01 2003-04-16 2012-12-31 -0.101152
# 120416     1.0  6282.0    IVZ  029804  02 2008-08-21 2019-12-31  0.023817
# 112968     3.0  7370.0   INTU  027928  01 2000-12-11 2019-12-31  0.066583
# 19214      1.0  6324.0     CI  002547  01 1982-04-08 2019-12-31 -0.027064
# 134250     1.0  7374.0    HPE  026156  01 2015-11-02 2019-12-31  0.046962

# %%
cnt = sp500ccm.groupby(['date'])['permno'].count().reset_index().rename(columns={'permno':'npermno'})
cnt.sample(4)
# Out:
#           date  npermno
# 44  2003-09-30      500
# 212 2017-09-29      501
# 84  2007-01-31      500
# 39  2003-04-30      500

# %%
sp500ccm.sample(10)
# Out:
#              date   permno                            comnam    ncusip  shrcd  \
# 113348 2014-11-28  26825.0                        KELLOGG CO  48783610   11.0
# 507    2000-01-31  80599.0      LEHMAN BROTHERS HOLDINGS INC  52490810   11.0
# 60387  2007-10-31  40272.0  INTERNATIONAL FLAVORS & FRAG INC  45950610   11.0
# 50310  2006-06-30  78034.0           PATTERSON COMPANIES INC  70339510   11.0
# 97932  2012-10-31  16600.0                        HERSHEY CO  42786610   11.0
# 70840  2009-02-27  24766.0             NORTHROP GRUMMAN CORP  66680710   11.0
# 23639  2002-12-31  13119.0                       MAYTAG CORP  57859210   11.0
# 112012 2014-09-30  28345.0                   MURPHY OIL CORP  62671710   11.0
# 93624  2012-03-30  52329.0      JACOBS ENGINEERING GROUP INC  46981410   11.0
# 114295 2015-01-30  91461.0                  WESTERN UNION CO  95980210   11.0
#
#         exchcd  hsiccd ticker   gvkey iid      start     ending       ret
# 113348     1.0  2043.0      K  006375  01 1961-04-26 2019-12-31  0.043465
# 507        1.0  6282.0    LEH  030128  01 1998-01-12 2008-09-16 -0.157934
# 60387      1.0  2869.0    IFF  006078  01 1976-03-04 2019-12-31 -0.012297
# 50310      3.0  5990.0   PDCO  025880  01 2005-10-11 2018-03-16  0.019854
# 97932      1.0  2066.0    HSY  005597  01 1957-03-01 2019-12-31 -0.028777
# 70840      1.0  3812.0    NOC  007985  01 1985-06-13 2019-12-31 -0.215295
# 23639      1.0  3633.0    MYG  007139  01 1960-12-14 2006-03-31 -0.079457
# 112012     1.0  1382.0    MUR  007620  01 2005-08-15 2017-07-25 -0.089003
# 93624      1.0  8711.0    JEC  006216  01 2007-10-26 2019-12-31 -0.040026
# 114295     1.0  6099.0     WU  175263  01 2006-10-02 2019-12-31 -0.050810

# %% [markdown]
# Save to CSV

# %%
sp500_full.sample(5)
# Out:
#          permno      start     ending       date       ret  \
# 1048620   16678 1957-03-01 2023-12-29 2023-04-28 -0.014989
# 1077758   24328 2022-10-03 2023-12-29 2023-12-29 -0.032533
# 752177    60943 1999-10-18 2021-12-17 2016-06-30  0.023677
# 311197    13856 1957-03-01 2023-12-29 2006-10-31 -0.027889
# 976286    77605 1995-02-24 2023-12-29 2021-07-30  0.066417
#
#                          comnam    ncusip     namedt   nameendt  shrcd  \
# 1048620               KROGER CO  50104410 2009-12-08 2023-12-29     11
# 1077758              E Q T CORP  26884L10 2017-12-12 2023-12-29     11
# 752177      LEGGETT & PLATT INC  52466010 2004-06-10 2017-01-10     11
# 311197              PEPSICO INC  71344810 2004-06-10 2017-12-19     11
# 976286   BOSTON SCIENTIFIC CORP  10113710 2004-06-10 2023-12-29     11
#
#          exchcd  hsiccd ticker
# 1048620       1    5411     KR
# 1077758       1    1311    EQT
# 752177        1    2515    LEG
# 311197        1    2086    PEP
# 976286        1    3841    BSX

# %%
sp500_full.to_csv('sp500_constituents.csv')

# %%
import yfinance as yf


# Function to get CIK by ticker
def get_cik_from_yfinance(tickers):
    cik_dict = {}
    for ticker in tickers:
        try:
            stock = yf.Ticker(ticker)
            cik = stock.info.get('CIK')
            cik_dict[ticker] = cik
            print(f"Ticker: {ticker}, CIK: {cik}")
        except Exception as e:
            print(f"Could not retrieve CIK for ticker {ticker}: {e}")
    return cik_dict

# Example usage with a list of tickers
tickers = ['AAPL', 'MSFT', 'GOOGL']
cik_dict = get_cik_from_yfinance(tickers)
# Out:
# Ticker: AAPL, CIK: None
# Ticker: MSFT, CIK: None
# Ticker: GOOGL, CIK: None
